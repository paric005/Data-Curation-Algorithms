# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
df = pd.read_csv("amazonsales.csv")
df.columns
import seaborn as sns

# %%
X = df.drop(columns =['Sales'])
y = df[['Sales']]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
Acsa = int(input("enter "))
print(model.predict([[Acsa,3,444,33,44,44,44]]))
# Out:
# enter  55
# [[282.50309529]]
# C:\Users\Parijat\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
sns.scatterplot(x=np.ravel(y_test), y=np.ravel(y_pred), color='blue', s=70)
# Out:
# <Axes: >

# %%
print(mean_squared_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 16.664191693877722
# 0.9997806364170896
